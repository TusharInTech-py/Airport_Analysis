# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings as wr
wr.filterwarnings('ignore')

# %%
data = pd.read_csv("Airline Dataset.csv")

# %%
data.head()
# Out:
#    Passenger ID First Name Last Name  Gender  Age Nationality  \
# 0         10856     Edithe    Leggis  Female   62       Japan
# 1         43872     Elwood      Catt    Male   62   Nicaragua
# 2         42633      Darby   Felgate    Male   67      Russia
# 3         78493   Dominica      Pyle  Female   71       China
# 4         82072        Bay   Pencost    Male   21       China
#
#                 Airport Name Airport Country Code   Country Name  \
# 0           Coldfoot Airport                   US  United States
# 1          Kugluktuk Airport                   CA         Canada
# 2     Grenoble-Isère Airport                   FR         France
# 3  Ottawa / Gatineau Airport                   CA         Canada
# 4            Gillespie Field                   US  United States
#
#   Airport Continent     Continents Departure Date Arrival Airport  \
# 0               NAM  North America      6/28/2022             CXF
# ...

# %%
data.tail()
# Out:
#        Passenger ID  First Name  Last Name  Gender  Age Nationality  \
# 98614         58454      Gareth    Mugford    Male   85       China
# 98615         22028       Kasey   Benedict  Female   19      Russia
# 98616         61732      Darrin     Lucken    Male   65   Indonesia
# 98617         19819       Gayle  Lievesley  Female   34       China
# 98618         14485  Wilhelmine     Touret  Female   10      Poland
#
#                       Airport Name Airport Country Code        Country Name  \
# 98614               Hasvik Airport                   NO              Norway
# 98615          Ampampamena Airport                   MG          Madagascar
# 98616  Albacete-Los Llanos Airport                   ES               Spain
# 98617               Gagnoa Airport                   CI       Côte d'Ivoire
# 98618          Yoshkar-Ola Airport                   RU  Russian Federation
#
#       Airport Continent Continents Departure Date Arrival Airport  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98619 entries, 0 to 98618
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Passenger ID          98619 non-null  int64
#  1   First Name            98619 non-null  object
#  2   Last Name             98619 non-null  object
#  3   Gender                98619 non-null  object
#  4   Age                   98619 non-null  int64
#  5   Nationality           98619 non-null  object
#  6   Airport Name          98619 non-null  object
#  7   Airport Country Code  98619 non-null  object
#  8   Country Name          98619 non-null  object
#  9   Airport Continent     98619 non-null  object
#  10  Continents            98619 non-null  object
#  11  Departure Date        98619 non-null  object
#  12  Arrival Airport       98619 non-null  object
#  13  Pilot Name            98619 non-null  object
#  14  Flight Status         98619 non-null  object
# ...

# %%
data.describe()
# Out:
#        Passenger ID           Age
# count  98619.000000  98619.000000
# mean   55168.689522     45.504021
# std    25985.443696     25.929849
# min    10000.000000      1.000000
# 25%    32608.000000     23.000000
# 50%    55338.000000     46.000000
# 75%    77695.000000     68.000000
# max    99999.000000     90.000000

# %%
data.isnull().sum()
# Out:
# Passenger ID            0
# First Name              0
# Last Name               0
# Gender                  0
# Age                     0
# Nationality             0
# Airport Name            0
# Airport Country Code    0
# Country Name            0
# Airport Continent       0
# Continents              0
# Departure Date          0
# Arrival Airport         0
# Pilot Name              0
# Flight Status           0
# dtype: int64

# %%
data.columns
# Out:
# Index(['Passenger ID', 'First Name', 'Last Name', 'Gender', 'Age',
#        'Nationality', 'Airport Name', 'Airport Country Code', 'Country Name',
#        'Airport Continent', 'Continents', 'Departure Date', 'Arrival Airport',
#        'Pilot Name', 'Flight Status'],
#       dtype='object')

# %%
print(data)
# Out:
#        Passenger ID  First Name  Last Name  Gender  Age Nationality  \
# 0             10856      Edithe     Leggis  Female   62       Japan
# 1             43872      Elwood       Catt    Male   62   Nicaragua
# 2             42633       Darby    Felgate    Male   67      Russia
# 3             78493    Dominica       Pyle  Female   71       China
# 4             82072         Bay    Pencost    Male   21       China
# ...             ...         ...        ...     ...  ...         ...
# 98614         58454      Gareth    Mugford    Male   85       China
# 98615         22028       Kasey   Benedict  Female   19      Russia
# 98616         61732      Darrin     Lucken    Male   65   Indonesia
# 98617         19819       Gayle  Lievesley  Female   34       China
# 98618         14485  Wilhelmine     Touret  Female   10      Poland
#
#                       Airport Name Airport Country Code        Country Name  \
# ...

# %%
ax = (data['Gender'].value_counts())
ax
# Out:
# Gender
# Male      49598
# Female    49021
# Name: count, dtype: int64

# %%
gender_c = data['Gender'].value_counts()
plt.pie(gender_c, labels=gender_c.index, autopct='%1.1f%%')
plt.legend()
plt.show()

# %%
ax = data['Nationality'].unique()
ax
# Out:
# array(['Japan', 'Nicaragua', 'Russia', 'China', 'Brazil', 'Ivory Coast',
#        'Vietnam', 'Palestinian Territory', 'Thailand', 'Tunisia',
#        'Sweden', 'Colombia', 'Greece', 'Philippines', 'Ukraine',
#        'Indonesia', 'Croatia', 'Democratic Republic of the Congo',
#        'France', 'Peru', 'Latvia', 'Germany', 'Czech Republic', 'Ireland',
#        'Iran', 'Madagascar', 'United States', 'Ghana', 'Mali',
#        'Guatemala', 'Kyrgyzstan', 'Haiti', 'Afghanistan', 'Ethiopia',
#        'Tanzania', 'Nigeria', 'Cameroon', 'Morocco', 'Armenia', 'Mexico',
#        'Chile', 'Albania', 'Luxembourg', 'Honduras', 'Portugal',
#        'Kazakhstan', 'Pakistan', 'Poland', 'South Africa', 'Kenya',
#        'Serbia', 'Maldives', 'Argentina', 'Uruguay', 'Netherlands',
#        'Botswana', 'Egypt', 'Syria', 'Myanmar', 'Slovenia', 'Spain',
#        'Macedonia', 'Mongolia', 'Yemen', 'Benin', 'Laos', 'Norway',
#        'Sao Tome and Principe', 'Venezuela', 'United Kingdom', 'Denmark',
# ...

# %%
ax = data['Nationality'].nunique()
ax
# Out:
# 240

# %%
ax = (data['Nationality'].value_counts())
ax
# Out:
# Nationality
# China                     18317
# Indonesia                 10559
# Russia                     5693
# Philippines                5239
# Brazil                     3791
#                           ...
# Romania                       2
# British Virgin Islands        2
# Jersey                        1
# Norfolk Island                1
# Sint Maarten                  1
# Name: count, Length: 240, dtype: int64

# %%
airline=data.copy()
airline.columns=[col.lower().replace(' ', '_') for col in airline.columns]
airline
# Out:
#        passenger_id  first_name  last_name  gender  age nationality  \
# 0             10856      Edithe     Leggis  Female   62       Japan
# 1             43872      Elwood       Catt    Male   62   Nicaragua
# 2             42633       Darby    Felgate    Male   67      Russia
# 3             78493    Dominica       Pyle  Female   71       China
# 4             82072         Bay    Pencost    Male   21       China
# ...             ...         ...        ...     ...  ...         ...
# 98614         58454      Gareth    Mugford    Male   85       China
# 98615         22028       Kasey   Benedict  Female   19      Russia
# 98616         61732      Darrin     Lucken    Male   65   Indonesia
# 98617         19819       Gayle  Lievesley  Female   34       China
# 98618         14485  Wilhelmine     Touret  Female   10      Poland
#
#                       airport_name airport_country_code        country_name  \
# ...

# %%
air = airline['departure_date'].dtypes
air
# Out:
# dtype('O')

# %%
# Ensure the column is treated as strings, and handle NaN values
air =airline['departure_date'] = airline['departure_date'].astype(str)

# Replace '-' with '/' and then convert to datetime
airline['departure_date'] = airline['departure_date'].str.replace('/', '-')
airline['departure_date'] = pd.to_datetime(airline['departure_date'])
airline['departure_date']
# Out:
# 0       2022-06-28
# 1       2022-12-26
# 2       2022-01-18
# 3       2022-09-16
# 4       2022-02-25
#            ...
# 98614   2022-12-11
# 98615   2022-10-30
# 98616   2022-09-10
# 98617   2022-10-26
# 98618   2022-04-16
# Name: departure_date, Length: 98619, dtype: datetime64[ns]

# %%
# Ensure 'departure_date' is treated as strings and handle NaN values
airline['departure_date'] = airline['departure_date'].astype(str)

# Replace '/' with '-' in the date strings
airline['departure_date'] = airline['departure_date'].str.replace('/', '-')

# Handle NaN values by replacing them with a default date or drop rows with NaN
airline['departure_date'] = airline['departure_date'].replace('nan', pd.NaT)

# Convert to datetime format
airline['departure_date'] = pd.to_datetime(airline['departure_date'], errors='coerce')

# Check the converted column
airline['departure_date']
# Out:
# 0       2022-06-28
# 1       2022-12-26
# 2       2022-01-18
# 3       2022-09-16
# 4       2022-02-25
#            ...
# 98614   2022-12-11
# 98615   2022-10-30
# 98616   2022-09-10
# 98617   2022-10-26
# 98618   2022-04-16
# Name: departure_date, Length: 98619, dtype: datetime64[ns]

# %%
airline['departure_date'].dtypes
# Out:
# dtype('<M8[ns]')

# %%
#airline = airline.set_index('departure_date'
airline
# Out:
#        passenger_id  first_name  last_name  gender  age nationality  \
# 0             10856      Edithe     Leggis  Female   62       Japan
# 1             43872      Elwood       Catt    Male   62   Nicaragua
# 2             42633       Darby    Felgate    Male   67      Russia
# 3             78493    Dominica       Pyle  Female   71       China
# 4             82072         Bay    Pencost    Male   21       China
# ...             ...         ...        ...     ...  ...         ...
# 98614         58454      Gareth    Mugford    Male   85       China
# 98615         22028       Kasey   Benedict  Female   19      Russia
# 98616         61732      Darrin     Lucken    Male   65   Indonesia
# 98617         19819       Gayle  Lievesley  Female   34       China
# 98618         14485  Wilhelmine     Touret  Female   10      Poland
#
#                       airport_name airport_country_code        country_name  \
# ...

# %%
def cat_age (string):
    # string=int(string)
    if str(string) == 'nan':
        return 'Unknown'
    elif int(string) <= 10:
        return 'Child'
    
    elif 10 <= int(string) <= 18:
        return 'Teen'
    
    elif 19 <= int(string) <= 45:
        return 'Adult'
    
    elif int(string) > 45:
        return 'Elder'

# %%
airline['age_group']=airline['age'].apply(cat_age)
airline.head()
# Out:
#    passenger_id first_name last_name  gender  age nationality  \
# 0         10856     Edithe    Leggis  Female   62       Japan
# 1         43872     Elwood      Catt    Male   62   Nicaragua
# 2         42633      Darby   Felgate    Male   67      Russia
# 3         78493   Dominica      Pyle  Female   71       China
# 4         82072        Bay   Pencost    Male   21       China
#
#                 airport_name airport_country_code   country_name  \
# 0           Coldfoot Airport                   US  United States
# 1          Kugluktuk Airport                   CA         Canada
# 2     Grenoble-Isère Airport                   FR         France
# 3  Ottawa / Gatineau Airport                   CA         Canada
# 4            Gillespie Field                   US  United States
#
#   airport_continent     continents departure_date arrival_airport  \
# 0               NAM  North America     2022-06-28             CXF
# ...

# %%
airline['age_group'].value_counts()
# Out:
# age_group
# Elder    49383
# Adult    29590
# Child    10896
# Teen      8750
# Name: count, dtype: int64

# %%
plt.figure(figsize=(5,5))
sns.countplot(x='age_group', data=airline, palette='Set2')

plt.xlabel('Age Group')
plt.ylabel('Count')
plt.title('Age Group Distribution')
plt.xticks(rotation=45)
plt.show()

# %%
airline.columns.tolist()
# Out:
# ['passenger_id',
#  'first_name',
#  'last_name',
#  'gender',
#  'age',
#  'nationality',
#  'airport_name',
#  'airport_country_code',
#  'country_name',
#  'airport_continent',
#  'continents',
#  'departure_date',
#  'arrival_airport',
#  'pilot_name',
#  'flight_status',
#  'age_group']

# %%
for col in airline.columns:
    print(col, airline[col].nunique())
# Out:
# passenger_id 59871
# first_name 8437
# last_name 41658
# gender 2
# age 90
# nationality 240
# airport_name 9062
# airport_country_code 235
# country_name 235
# airport_continent 6
# continents 6
# departure_date 364
# arrival_airport 9024
# pilot_name 98610
# flight_status 3
# age_group 4

# %%
# Donut chart
flight_status_count = airline['flight_status'].value_counts()
plt.figure(figsize=(7, 7))
plt.pie(flight_status_count, labels=flight_status_count.index, autopct='%1.1f%%', startangle=90, colors=sns.color_palette('Set2'))
# Create the hole in the middle
centre_circle = plt.Circle((0, 0), 0.70, fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.title('Flight Status Distribution')
plt.show()

# %%
airline.groupby(['age_group', 'flight_status']).size().unstack()
# Out:
# flight_status  Cancelled  Delayed  On Time
# age_group
# Adult               9903     9801     9886
# Child               3618     3655     3623
# Elder              16490    16496    16397
# Teen                2931     2879     2940

# %%
import plotly.express as px

df_grouped = airline.groupby(['age_group', 'flight_status']).size().reset_index(name='count')

fig = px.bar(df_grouped, 
             x='age_group', 
             y='count', 
             color='flight_status',
             barmode='group',  # Grouped bar plot
             title='Flight Status Based on Age Group')

fig.update_layout(xaxis_title='Passenger Age Group', yaxis_title='Count')
fig.show()

# %%
import plotly.express as px
import pandas as pd
df_grouped = airline.groupby(['continents', 'gender']).size().reset_index(name='count')
fig = px.bar(df_grouped, 
             x='continents', 
             y='count', 
             color='gender', 
             barmode='group', 
             title='Gender Distribution Across Continents')
fig.update_layout(xaxis_title='Continents', yaxis_title='Count')
fig.show()

# %%
airline.columns
# Out:
# Index(['passenger_id', 'first_name', 'last_name', 'gender', 'age',
#        'nationality', 'airport_name', 'airport_country_code', 'country_name',
#        'airport_continent', 'continents', 'departure_date', 'arrival_airport',
#        'pilot_name', 'flight_status', 'age_group'],
#       dtype='object')

# %%
import plotly.express as px

#  top 20 nationality-gender combinations by count
top_20_nations = airline[['nationality', 'gender']].value_counts().nlargest(20).reset_index(name='count')
fig = px.bar(top_20_nations, 
             x='nationality', 
             y='count', 
             color='gender', 
             barmode='group', 
             title='Top 20 Nations by Gender Distribution',
             color_discrete_sequence=px.colors.qualitative.Plotly)
fig.update
fig.show()

# %%
import plotly.express as px

# top 10 airports
top_10_airports = airline['airport_name'].value_counts().nlargest(10)
fig = px.bar(top_10_airports, 
             x=top_10_airports.index, 
             y=top_10_airports.values, 
              color='count',
             title='Top 10 Airports')
fig.show()

# %%
airline[['airport_name', 'gender']].value_counts().nlargest(10).reset_index()
# Out:
#            airport_name  gender  count
# 0     San Pedro Airport    Male     22
# 1   Santa Maria Airport  Female     22
# 2     San Pedro Airport  Female     21
# 3     Santa Ana Airport    Male     19
# 4  San Fernando Airport    Male     19
# 5        Kiunga Airport    Male     19
# 6  Grant County Airport    Male     18
# 7    Böblingen Flugfeld  Female     18
# 8       Herrera Airport  Female     18
# 9    Böblingen Flugfeld    Male     18

# %%
def plot_top_groupbar (data, x_column, legend_column, size=10):
    
    top=airline[x_column].value_counts().nlargest(size).index.to_list()
    data=data[data[x_column].isin(top)]
  
    data.groupby([x_column, legend_column]).size().unstack().plot(kind='bar', stacked=False, figsize=(10, 6))
    plt.title(f'{legend_column} based on {x_column}')
    plt.xlabel(f'Passenger {x_column}')
    plt.ylabel('Count')
    plt.show()

# %%
plot_top_groupbar(airline, 'airport_name', 'gender', size=30)

# %%
plot_top_groupbar(airline, 'nationality', 'gender', size=10)

# %%
airline.head()
# Out:
#    passenger_id first_name last_name  gender  age nationality  \
# 0         10856     Edithe    Leggis  Female   62       Japan
# 1         43872     Elwood      Catt    Male   62   Nicaragua
# 2         42633      Darby   Felgate    Male   67      Russia
# 3         78493   Dominica      Pyle  Female   71       China
# 4         82072        Bay   Pencost    Male   21       China
#
#                 airport_name airport_country_code   country_name  \
# 0           Coldfoot Airport                   US  United States
# 1          Kugluktuk Airport                   CA         Canada
# 2     Grenoble-Isère Airport                   FR         France
# 3  Ottawa / Gatineau Airport                   CA         Canada
# 4            Gillespie Field                   US  United States
#
#   airport_continent     continents departure_date arrival_airport  \
# 0               NAM  North America     2022-06-28             CXF
# ...

# %%
airline.columns
# Out:
# Index(['passenger_id', 'first_name', 'last_name', 'gender', 'age',
#        'nationality', 'airport_name', 'airport_country_code', 'country_name',
#        'airport_continent', 'continents', 'departure_date', 'arrival_airport',
#        'pilot_name', 'flight_status', 'age_group'],
#       dtype='object')

# %%
airline['departure_day'] = airline['departure_date'].dt.day_name()  # Extract day name
print("Busiest days for flights:")
airline['departure_day'].value_counts()
# Out:
# Busiest days for flights:
# departure_day
# Sunday       14289
# Friday       14227
# Thursday     14227
# Tuesday      14048
# Monday       14032
# Wednesday    13939
# Saturday     13857
# Name: count, dtype: int64

# %%
plot_top_groupbar(airline, 'departure_day', 'flight_status', size=10)

# %%
airline['departure_month'] = airline['departure_date'].dt.month  # Extract month name
print("Busiest months for flights:")
airline['departure_month'].value_counts()
# Out:
# Busiest months for flights:
# departure_month
# 8     8544
# 5     8496
# 7     8451
# 3     8431
# 1     8416
# 10    8415
# 9     8149
# 6     8128
# 11    8053
# 4     7959
# 12    7924
# 2     7653
# Name: count, dtype: int64

# %%
plot_top_groupbar(airline, 'departure_month', 'flight_status', size=12)
